# %%
import torch_explore
import har_transformer

# %%
labels = ['label:LYING_DOWN',
 'label:SITTING',
 'label:FIX_walking',
 'label:FIX_running',
 'label:BICYCLING',
 'label:SLEEPING',
 'label:LAB_WORK',
 'label:IN_CLASS',
 'label:IN_A_MEETING',
 'label:LOC_main_workplace',
 'label:OR_indoors',
 'label:OR_outside',
 'label:IN_A_CAR',
 'label:ON_A_BUS',
 'label:DRIVE_-_I_M_THE_DRIVER',
 'label:DRIVE_-_I_M_A_PASSENGER',
 'label:LOC_home',
 'label:FIX_restaurant',
 'label:PHONE_IN_POCKET',
 'label:OR_exercise',
 'label:COOKING',
 'label:SHOPPING',
 'label:STROLLING',
 'label:DRINKING__ALCOHOL_',
 'label:BATHING_-_SHOWER',
 'label:CLEANING',
 'label:DOING_LAUNDRY',
 'label:WASHING_DISHES',
 'label:WATCHING_TV',
 'label:SURFING_THE_INTERNET',
 'label:AT_A_PARTY',
 'label:AT_A_BAR',
 'label:LOC_beach',
 'label:SINGING',
 'label:TALKING',
 'label:COMPUTER_WORK',
 'label:EATING',
 'label:TOILET',
 'label:GROOMING',
 'label:DRESSING',
 'label:AT_THE_GYM',
 'label:STAIRS_-_GOING_UP',
 'label:STAIRS_-_GOING_DOWN',
 'label:ELEVATOR',
 'label:OR_standing',
 'label:AT_SCHOOL',
 'label:PHONE_IN_HAND',
 'label:PHONE_IN_BAG',
 'label:PHONE_ON_TABLE',
 'label:WITH_CO-WORKERS',
 'label:WITH_FRIENDS']

# %%
folderpath = 'data/full_data'
path_exp = 'data/full_data/exp_uni'
final_filename = 'all_users'

har_transformer.create_unified_csv(folderpath, path_exp, final_filename)
# Out:
#        timestamp  raw_acc:magnitude_stats:mean  raw_acc:magnitude_stats:std  \
# 0     1446762297                      1.057536                     0.040597
# 1     1446762357                      1.057436                     0.006165
# 2     1446762417                      1.056344                     0.006302
# 3     1446762487                      1.056874                     0.004767
# 4     1446762548                      1.057353                     0.005415
# ...          ...                           ...                          ...
# 1595  1448259712                      1.021137                     0.020418
# 1596  1448259772                      1.017365                     0.016336
# 1597  1448308475                      1.020871                     0.019622
# 1598  1448312089                      1.007060                     0.064150
# 1599  1448312150                      1.000381                     0.005864
#
# ...

# %%
config = {
        'data_params': {
            'labels': labels,
            #'data_csv': 'data/sample_data/00EABED2-271D-49D8-B599-1D4A09240601.features_labels.csv',
            'data_csv': 'data/full_data/exp_uni/all_users.csv',
        },
        'transformer_params': {
            'transformers_layers': 6, 
            'n_positions': 128,
            'hidden_size': 360, #768,
        },

        'training_params': {
            'batch_size': 32,
            'epochs': 10,
        }

    }

# %%
torch_explore.main(config)
# Out:
# df label indices with only one instance:  [377180, 376435, 376367, 376236, 375828, 374083, 360659, 354927, 353564, 352879, 350868, 349811, 349458, 348104, 347038, 346970, 346440, 345594, 344246, 339443, 337540, 337353, 329382, 328145, 321872, 321754, 321226, 320550, 317988, 309154, 303693, 290478, 290324, 287693, 278093, 278092, 271460, 261472, 260410, 259283, 259088, 258583, 255921, 254332, 250159, 247810, 238782, 237641, 235377, 235043, 235042, 234152, 232675, 229715, 228608, 223970, 221238, 217939, 216917, 216205, 213911, 211049, 211048, 210842, 202793, 202437, 200261, 176713, 175416, 174997, 174878, 173997, 173896, 173849, 173807, 173590, 169409, 166035, 165958, 163722, 163285, 162594, 162351, 162263, 162176, 161368, 161361, 161169, 159436, 159435, 158364, 158363, 158195, 157865, 157763, 157385, 157361, 149123, 147404, 142966, 140766, 139946, 139945, 139493, 134331, 125369, 125335, 124581, 115637, 114531, 113746, 102142, 99494, 99001, 98744, 92686, 83808, 82053, 81388, 75191, 704
# ...
